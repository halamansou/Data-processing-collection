# %%
from tkinter import *
from tkinter import filedialog
import pandas as pd
import numpy as np
from sklearn.feature_selection import RFE
from sklearn import svm
from sklearn.svm import SVC
from tkinter import messagebox
from sklearn import tree
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split 
from sklearn import metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
root = Tk()
root.title('Project')
root.geometry('500x500')


def load_data():
    global filepath 
    filepath = filedialog.askopenfilename() 
    
    global data 
    data = pd.read_csv(filepath)
    global X
    X = data.iloc[:,:-1]
    global y 
    y = data.iloc[:,-1]

def Accu_tree():
    
    a=accuracy_score( y_test, y_pred)
    x=str(a);
    lab1 = Label(text='accuracy_score'+x)
    lab1.pack()
    lab1.place(x= 100,y=350)
    
def tree_plot():
    
      # plot tree
    
    df1 = pd.DataFrame(tree_data)
    figure1 = plt.Figure(figsize=(12,12), dpi=100)
    ax1 = figure1.add_subplot(111)
    bar1 = FigureCanvasTkAgg(figure1, root)
    bar1.get_tk_widget().pack(side=tk.LEFT, fill=tk.BOTH)
    df1.plot(kind='bar', legend=True, ax=ax1)
    ax1.set_title('Decision Tree')
    
def sixth_page():
    fr6=Frame(width=800,height=500,bg='red')
    fr6.place(x=320,y=1)
    lbl_1=Label(fr6,text='Welcom in Descition Tree' ,font=100)
    lbl_1.place(x=200,y=30)
    ##load Data
    load_btn_5 = Button(fr6,text='load data',command=load_data,font=('Roboto',20),bg='orange',fg='white')
    load_btn_5.place(x=200,y=70)
    #Acc
    But_Accu = Button(fr6,text='Accuracy',command=Accu_tree,font=('Roboto',15),bg='orange',fg='white',width=10,height=1)
    But_Accu.place(x= 100,y=250)
    
    ##
    label6 = Label(fr6,text="Test_size",font=('Roboto',15))
    label6.place(x=100,y=130)
    global e5 
    e6 = Entry(fr6)
    e6.place(x=200,y=130)
    
    label5 = Label(fr6,text="Max Depth",font=('Roboto',15))
    label5.place(x=100,y=200)
    global e5 
    e5 = Entry(fr6)
    e5.place(x=210,y=200)
    
    
     #plot
    plot = Button(fr6,text='plot',command=tree_plot,font=('Roboto',15),bg='orange',fg='white',width=10,height=1)
    plot.place(x= 250,y=250)
    
    global tree_data
    tree_data = pd.read_csv("E:\\semester7\\Machine Learning\\sec\\new_data.csv")
    global X
    global y
    X = tree_data.iloc[:,:-1]
    y = tree_data.iloc[:,-1]
    global X_test
    global X_train
    global y_test
    global y_train
    X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=float(e6.get()),random_state=42)
    global clf
    clf = tree.DecisionTreeClassifier(max_depth=float(e5.get()))
    clf = clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test) 
    
    
    

fr5=Frame(width='300',height='700',bg='blue')
fr5.place(x=1,y=1)
DT_btn = Button(fr5,text='Decision Tree',command=sixth_page,font=('Roboto',15),bg='orange',fg='white')
DT_btn.place(x= 20,y=20)
    



fr1 = Frame(root)
#button1 = Button(fr1,text='Classification',command=secondPage,font=('Roboto',15),bg='#F08080',fg='white')
#button1.pack(side=TOP)
fr1.pack(expand=True)

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\20109\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\20109\AppData\Local\Temp\ipykernel_1868\661065232.py", line 68, in sixth_page
#     tree_data = pd.read_csv("E:\\semester7\\Machine Learning\\sec\\new_data.csv")
#   File "C:\Users\20109\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\20109\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 680, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "C:\Users\20109\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 575, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "C:\Users\20109\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 933, in __init__
#     self._engine = self._make_engine(f, self.engine)
# ...
